# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tbl1 = pd.read_csv('data_assignment2.csv')  ## living area vs price

# %%
tbl1
# Out:
#     ID  Living_area  Rooms  Land_size  Biarea  Age  Selling_price
# 0    1          104    5.0      271.0    25.0   33        4600000
# 1    2           99    5.0     1506.0     6.0   88        4450000
# 2    3          133    6.0      486.0     NaN   44        4900000
# 3    4          175    7.0      728.0     NaN   14        6625000
# 4    5          118    6.0     1506.0     NaN   29        4600000
# 5    6          133    6.0      823.0     NaN   12        6650000
# 6    7           70    4.0     1685.0    70.0   53        2800000
# 7    8          134    6.0     1593.0    49.0   57        6100000
# 8    9           70    5.0     1120.0   102.0   81        3000000
# 9   10          133    6.0     1503.0     NaN   51        3000000
# 10  11          121    4.0     1575.0   112.0   81        4000000
# 11  12          136    6.0      381.0     NaN   42        4350000
# 12  13           86    4.0     1529.0    30.0   90        3025000
# ...

# %%
tbl1['Living_area'].
# Out:
# 0     104
# 1      99
# 2     133
# 3     175
# 4     118
# 5     133
# 6      70
# 7     134
# 8      70
# 9     133
# 10    121
# 11    136
# 12     86
# 13    135
# 14    130
# 15    104
# 16     66
# 17    129
# 18     75
# 19    160
# 20     87
# 21    182
# 22    135
# 23    100
# 24    202
# 25    136
# 26    185
# 27    153
# 28    135
# 29     73
# 30    120
# 31    122
# 32     63
# 33    150
# 34    210
# 35    108
# 36    111
# 37     72
# 38    170
# 39    142
# 40    170
# 41    120
# 42    107
# 43    135
# 44    145
# 45    168
# 46     69
# 47    170
# 48    160
# 49    170
# 50    158
# 51    103
# 52    148
# 53    139
# 54    118
# 55    159
# Name: Living_area, dtype: int64

# %%
x = tbl1['Living_area']
y = tbl1['Selling_price']
model = numpy.poly1d(numpy.polyfit(x, y, 1))

line = numpy.linspace(0, max(x), 10)
plt.plot(line, model(line),color='red')
plt.scatter(x, y)


plt.title(label="Living_area vs selling price",
          fontsize=20
         )
plt.show()

# %%
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 210, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);


plt.scatter(x,y)
plt.scatter(10, model.predict([[10]]), label='10')
plt.scatter(50, model.predict([[50]]), label='50')
plt.scatter(100, model.predict([[100]]), label='100')
plt.scatter(150, model.predict([[150]]), label='150')
plt.scatter(200, model.predict([[200]]), label='200')
plt.legend()
plt.show()
# Out:
# /var/folders/t1/y2wlw9zs1kv6x4cp10gk5h0h0000gn/T/ipykernel_15725/2178526285.py:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   model.fit(x[:, np.newaxis], y)

# %%
plt.scatter(x, y)
plt.plot(xfit, yfit);


plt.scatter(x,y)
plt.scatter(10, model.predict([[10]]), label='10')
plt.scatter(50, model.predict([[50]]), label='50')
plt.scatter(100, model.predict([[100]]), label='100')
plt.scatter(150, model.predict([[150]]), label='150')
plt.scatter(200, model.predict([[200]]), label='200')
plt.scatter(1000, model.predict([[1000]]), label='1000')
plt.legend()


plt.show()

# %%
#plt.boxplot(tbl1['Selling_price'])

# %%
model.coef_
# Out:
# array([19370.13854733])

# %%
model.intercept_
# Out:
# 2220603.2433558684

# %%
model.predict([[20]])
# Out:
# array([2608006.0143025])
